# %%
import os
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import requests

# %%
labels = ["0", "1", "2", "3", "4", "5", "6", "7"]
folder_path = os.path.join(os.path.abspath(os.pardir), "Langchain")
folder_path
# Out:
# '/home/aia/Nhat/ChatGPT-Conversation/Langchain'

# %%
file_path = os.path.join(folder_path, "sales_1xx.xlsx")
df = pd.read_excel(file_path, dtype=str, keep_default_na=False)

df = df[df["label"].isin(labels)]
print(df.shape)
for i in range(8):
    print(i, list(df.label).count(str(i)))
    
X = df[["comment", "category", "new_label"]]
y = df["label"] # tmp
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2
# Out:
# (832, 4)
# 0 199
# 1 116
# 2 113
# 3 163
# 4 21
# 5 35
# 6 152
# 7 33

# %%
X_train
# Out:
#                                                comment category new_label
# 670                                      Toàn hàng đẹp  grocery         6
# 248                                     Tặng 2 50k 665   others         1
# 696  Chỉ nhận dk set 215k kem thắt lưng màu rồi Đẹp...   others         6
# 726        Mới đặc hôm qua mà hôm nay đã có nhanh thật      fnb         6
# 111  Bên em nhận được chưa  chị đã gởi tiền rồi  ti...      fnb         0
# ..                                                 ...      ...       ...
# 715           C Ngọc Anh dễ thương lại bán hàng có tâm  grocery         6
# 767                                 Khăn này tuyệt đẹp  grocery         6
# 72                        Kajsbsbdbhsbdbdbdbdbdbdbdbsb   others         0
# 235                                              An An   others         1
# 37   hôm nay chị vừa nhận được khăn tắm đẹp lắm gái ah  grocery         6
#
# [748 rows x 3 columns]

# %%
dictionaries = dict()
for i in range(8):
    # get data
    tmp = X_train[X_train["new_label"]==str(i)]
    tmp = tmp.reset_index(drop=True)
    dictionaries[i] = list()
    for j in range(len(tmp)):
        comment = tmp.comment[j]
        if comment not in dictionaries[i]:
            dictionaries[i].append(comment)
with open("sample.json", "w") as outfile:
    json.dump(dictionaries, outfile)

# %%
import textdistance

# %%
dictionary_df = X_train.copy()
dictionary_df = dictionary_df.reset_index(drop=True)
dictionary_df
# Out:
#                                                comment category new_label
# 0                                        Toàn hàng đẹp  grocery         6
# 1                                       Tặng 2 50k 665   others         1
# 2    Chỉ nhận dk set 215k kem thắt lưng màu rồi Đẹp...   others         6
# 3          Mới đặc hôm qua mà hôm nay đã có nhanh thật      fnb         6
# 4    Bên em nhận được chưa  chị đã gởi tiền rồi  ti...      fnb         0
# ..                                                 ...      ...       ...
# 743           C Ngọc Anh dễ thương lại bán hàng có tâm  grocery         6
# 744                                 Khăn này tuyệt đẹp  grocery         6
# 745                       Kajsbsbdbhsbdbdbdbdbdbdbdbsb   others         0
# 746                                              An An   others         1
# 747  hôm nay chị vừa nhận được khăn tắm đẹp lắm gái ah  grocery         6
#
# [748 rows x 3 columns]

# %%
def top_nearest_df(comment):
    N = 5
    similar = [textdistance.bz2_ncd.similarity(comment, _) for _ in dictionary_df.comment]
    res = sorted(range(len(similar)), key = lambda sub: similar[sub])[-N:]
    return dictionary_df.iloc[res, :]

# %%
label_to_text = [str(_) for _ in range(8)]
label_to_text
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']

# %%
question_df = pd.DataFrame()
for label in labels:
    tmp = X_test[X_test["new_label"] == label]
    tmp = tmp.sample(n=min(len(tmp), 30), replace=False)
    question_df = pd.concat([question_df, tmp], axis=0)
print(question_df.shape)
question_df
# question_df = X_test.copy()
# question_df
# Out:
# (84, 3)
#                                                comment   category new_label
# 435                           Lên bông tai xuping di e  accessory         0
# 65                                              Ádffff     others         0
# 94   anh chị ở chợ nguyen tri phương  tiệm vang ngo...        fnb         0
# 81                            Chị nói chuyen dễ thương        fnb         0
# 50                                     Lôn đanh gì chi        fnb         0
# ..                                                 ...        ...       ...
# 807                                            Huỷ B40     others         7
# 819                                    B44 huỷ b43 dồn     others         7
# 816            chi xả con đầu rồng đỏ lúc trước có rồi     others         7
# 808                              Xả c jum quẩn dài nha     others         7
# 804                                 Xả Jum dùm chị nhe     others         7
#
# [84 rows x 3 columns]

# %%
from langchain import PromptTemplate, FewShotPromptTemplate

# %%
def examples_generator(comment=""): # return a list of dict()
    examples = []
    nearest_df = top_nearest_df(comment)
    for ind in range(len(nearest_df)):
        row = nearest_df.iloc[ind]
        example = dict()
        example["comment"] = row.comment
        example["category"] = row.category
        example["label"] = row.new_label
        # example["mean"] = ?
        examples.append(example)
    return examples

# %%
examples_generator("Thanh Khang")
# Out:
# [{'comment': 'Xanh ni 8', 'category': 'accessory', 'label': '3'},
#  {'comment': 'Tang 640', 'category': 'clothing', 'label': '1'},
#  {'comment': 'Tang 640', 'category': 'clothing', 'label': '1'},
#  {'comment': 'Thu Trang', 'category': 'fnb', 'label': '1'},
#  {'comment': 'Anh Van', 'category': 'clothing', 'label': '1'}]

# %%
def fewshot_prompt_generator(comment="", category=""):
    
    def prefix_generator():
        prefix = """Trong livestream bán hàng,
        Nếu nhắc tên người khác, muốn chia sẻ thì nhãn là 1.
        Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2.
        Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3.
        Nếu chốt đơn thì nhãn là 4.
        Nếu đánh giá tiêu cực, không thích thì nhãn là 5.
        Nếu đánh giá tích cực, hứng thú thì nhãn là 6.
        Nếu muốn xả hàng, muốn hủy đơn hàng thì nhãn là 7.
        Còn lại thì nhãn là 0.""".replace("\n", " ").replace("    ", "")
        return prefix
    
    
    def suffix_generator(comment="", category=""):
        suffix = 'Hãy chọn đáp án cho bình luận "' + comment + '" về sản phẩm ' + category + "."
        return suffix
    
    
    def fewshot_generator(prefix, examples, suffix):
        example_formatter_template = """ Ví dụ bình luận "{comment}" về sản phẩm {category} thì nhãn là {label}."""
        example_prompt = PromptTemplate(
            input_variables = ["comment", "category", "label"],
            template = example_formatter_template,
        ) 
        
        few_shot_prompt = FewShotPromptTemplate(
            examples = examples,
            example_prompt = example_prompt,
            prefix = prefix,
            suffix = suffix,
            input_variables = [],
            example_separator = "",
        )
        
        return few_shot_prompt
    
    prefix = prefix_generator()
    examples = examples_generator(comment=comment)
    suffix = suffix_generator(comment=comment, category=category)
    
    few_shot_prompt = fewshot_generator(prefix=prefix, examples=examples, suffix=suffix)
    prompt = few_shot_prompt.format()
    prompt = prompt + ' Trả lời theo định dạng json: {"reason": lý do chọn, "labels": 2 nhãn phù hợp nhất}'
    prompt = prompt.replace("\n", " ").replace("    ", "")
    
    return prompt

# %%
print(fewshot_prompt_generator(comment="cai dong ho dep lam c nhung kh co mau em thik", category="accessories"))
# Out:
# Trong livestream bán hàng, Nếu nhắc tên người khác, muốn chia sẻ thì nhãn là 1. Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2. Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3. Nếu chốt đơn thì nhãn là 4. Nếu đánh giá tiêu cực, không thích thì nhãn là 5. Nếu đánh giá tích cực, hứng thú thì nhãn là 6. Nếu muốn xả hàng, muốn hủy đơn hàng thì nhãn là 7. Còn lại thì nhãn là 0. Ví dụ bình luận "Chi ban kem trang da ma vua gioi nua" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "Rat dep chuan nhung sai nho" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "May bua dt chi bi chuong hu nen kg nghe dc" về sản phẩm accessory thì nhãn là 0. Ví dụ bình luận "e nhan kem roi c kem xai suong lm thom lm luon" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "Chi chon cai dong ho mau nau den nhe" về sản phẩm accessory thì nhãn là 4.Hãy chọn đáp án cho bình luận "cai dong ho dep lam c nhung kh co mau em thik" về sản phẩm accessories. Trả lời theo định dạng json: {"reason": lý do chọn, "labels": 2 nhãn phù hợp nhất}

# %%
def output_to_json(output): # Post-processing
    try:
        i = output.index("{")
        j = len(output) - output[::-1].index("}") - 1
        res = json.loads(output[i:j+1])
    except:
        res = {}
    return res

# %%
labels_form = '{"top_1": nhãn phù hợp nhất, "top_2": nhãn phù hợp nhì}'
output_form = '{"label": nhãn thích hợp hơn, "explain": giải thích ngắn}'

comment_label_prompt_template = PromptTemplate(
    input_variables=["comment", "category", "labels_form"],
    template="""Nếu nhắc tên người khác, chia sẻ thì nhãn là 1.
    Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2.
    Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3.
    Nếu chốt đơn thì nhãn là 4.
    Nếu đánh giá tiêu cực, không thích thì nhãn là 5.
    Nếu đánh giá tích cực, hứng thú thì nhãn là 6.
    Nếu muốn xả hàng, muốn hủy đơn hàng hoặc không muốn nhận hàng thì nhãn là 7.
    Các trường hợp khác hoặc không phân tích được thì nhãn là 0.
    "{comment}" trong livestream mặt hàng {category} sẽ thuộc những nhãn nào. Trả về dạng json {labels_form}.
    """.replace("\n", " ").replace("    ", ""),
)

comment_confirm_prompt_template = PromptTemplate(
    input_variables=["top_1", "top_2", "comment", "output_form"],
    template="""Nếu nhắc tên người khác, chia sẻ thì nhãn là 1.
    Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2.
    Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3.
    Nếu chốt đơn thì nhãn là 4.
    Nếu đánh giá tiêu cực, không thích thì nhãn là 5.
    Nếu đánh giá tích cực, hứng thú thì nhãn là 6.
    Nếu muốn xả hàng, muốn hủy đơn hàng hoặc không muốn nhận hàng thì nhãn là 7.
    Các trường hợp khác hoặc không phân tích được thì nhãn là 0.
    "{top_1}" hay "{top_2}" là nhãn thích hợp hơn cho "{comment}"?. Trả dạng json {output_form}.
    """.replace("\n", " ").replace("    ", ""),
)

# %%
api = 'http://localhost:8081/labelling'
labels_form = '{"top_1": nhãn phù hợp nhất, "top_2": nhãn phù hợp nhì}'
output_form = '{"mean": ý nghĩa bình luận, "label": nhãn phù hợp nhất}'

# %%
def free_chain(comment="", category=""):
    x1 = comment_label_prompt_template.format(
        comment=comment,
        category=category,
        labels_form=labels_form
    )
    form_data_1 = {'prompt': x1}
    response_1 = requests.post(api, data=form_data_1).text
    response_json_1 = output_to_json(response_1)
    
    x1_output = output_to_json(response_json_1['output'])
    print(x1_output)
    top_1, top_2 = x1_output["top_1"], x1_output["top_2"]
    
    x2 = comment_confirm_prompt_template.format(
        top_1=top_1,
        top_2=top_2,
        comment=comment,
        output_form=output_form
    )
    form_data_2 = {'prompt': x2}
    response_2 = requests.post(api, data=form_data_2).text
    response_json_2 = output_to_json(response_2)
    x2_output = output_to_json(response_json_2['output'])
    print(x2_output)
    return x2_output

# %%
import time

# %%
cur_time = time.time()
test_comment = "Tặng 2 50k 665"
test_category = "clothing"
test_result = free_chain(comment=test_comment, category=test_category)
print(time.time()-cur_time)
test_result
# Out:
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Tặng 2 50k 665', 'label': 3}
# 18.228149890899658
# {'mean': 'Tặng 2 50k 665', 'label': 3}

# %%
y_pred, y_true, y_mean = [], [], []
y_comment, y_category = [], []

for i in range(len(question_df)):
    
    print("time-------->", i)
    row = question_df.iloc[i]
    y_category.append(row["category"])
    y_comment.append(row["comment"])
    y_true.append(label_to_text[int(row["new_label"])])
    try:
        res = free_chain(comment=row["comment"], category=row["category"])
        pred = str(res['label'])
        mean = res['mean']
    except Exception as e:
        res = {
            'mean': e,
            'label': 0,
        }
        pred = str(res['label'])
        mean = res['mean']
        
    y_pred.append(pred)
    y_mean.append(mean)
    
print("Done.")
# Out:
# time--------> 0
# {'top_1': 3, 'top_2': 6}
# {'mean': 'Lên bông tai xuping đi em', 'label': 3}
# time--------> 1
# {'top_1': 0, 'top_2': 0}
# {'mean': 'Ádffff', 'label': 0}
# time--------> 2
# {'top_1': 2, 'top_2': 0}
# {'mean': 'anh chị ở chợ Nguyễn Tri Phương tiệm Vàng Ngọc Hà', 'label': 2}
# time--------> 3
# {'top_1': 0, 'top_2': None}
# {'mean': 'Chị nói chuyện dễ thương', 'label': 0}
# time--------> 4
# {'top_1': 0, 'top_2': 0}
# {'mean': 'Lôn đanh gì chi', 'label': 0}
# time--------> 5
# {'top_1': 0, 'top_2': 0}
# {'mean': '.', 'label': 0}
# time--------> 6
# {'top_1': 4, 'top_2': 0}
# {'mean': 'Có chốt e chưa ạ ánh hồng', 'label': 4}
# time--------> 7
# {'top_1': 2, 'top_2': 0}
# {'mean': 'Hi 2 chú', 'label': 2}
# time--------> 8
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Lên quạt xạc cầm tay đi NA', 'label': 3}
# time--------> 9
# {'top_1': 2, 'top_2': 0}
# {'mean': '2', 'label': 2}
# time--------> 10
# {'top_1': 2, 'top_2': 0}
# {'mean': 'Chấm', 'label': 2}
# time--------> 11
# {'top_1': 2, 'top_2': 0}
# {'mean': 'oh vậy thôi', 'label': 2}
# time--------> 12
# time--------> 13
# {'top_1': 4, 'top_2': 0}
# {'mean': 'kim nguyen chốt giống máy bay', 'label': 4}
# time--------> 14
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Hàng hôm kia', 'label': 3}
# time--------> 15
# {'top_1': 0, 'top_2': 0}
# {'mean': '0', 'label': 0}
# time--------> 16
# {'top_1': 1, 'top_2': 0}
# {'mean': 'Đọc đúng tên rồi đó', 'label': 1}
# time--------> 17
# {'top_1': 3, 'top_2': 0}
# {'mean': '3', 'label': 3}
# time--------> 18
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Chăn đi Na', 'label': 3}
# time--------> 19
# {'top_1': 0, 'top_2': 0}
# {'mean': 'Ctfiyc', 'label': 0}
# time--------> 20
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Dồn đơn bữa chưa gọi nka thảo', 'label': 0}
# time--------> 21
# {'top_1': 3, 'top_2': 1}
# {'mean': 'Chuẩn kem trộn Tp cần thơ', 'label': 3}
# time--------> 22
# {'top_1': 6, 'top_2': 0}
# {'mean': 'E mua mấy lần rùi chị chút e ib đc nha', 'label': 6}
# time--------> 23
# {'top_1': 6, 'top_2': 0}
# {'mean': 'Kk', 'label': 0}
# time--------> 24
# {'top_1': 1, 'top_2': 0}
# {'mean': 'Đcs', 'label': 1}
# time--------> 25
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Tặng 3 50k 638', 'label': 3}
# time--------> 26
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Tặng 560', 'label': 3}
# time--------> 27
# {'top_1': 3, 'top_2': 6}
# {'mean': 'tặng 824', 'label': 6}
# time--------> 28
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Tặng 3 50k 963', 'label': 3}
# time--------> 29
# {'top_1': 1, 'top_2': 0}
# {'mean': '', 'label': 0}
# time--------> 30
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Tang 476', 'label': 3}
# time--------> 31
# {'top_1': 2, 'top_2': 0}
# {'mean': 'Em seo đồng hồ cũ của em chưa', 'label': 2}
# time--------> 32
# {'top_1': 3, 'top_2': 0}
# {'mean': 'túi gia bn e', 'label': 3}
# time--------> 33
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Balô tôm còn kg Shopee', 'label': 3}
# time--------> 34
# {'top_1': 4, 'top_2': 0}
# {'mean': 'Đơn hôm kia gọi chốt hết chưa em', 'label': 4}
# time--------> 35
# {'top_1': 0, 'top_2': 0}
# {'mean': 'Ng lớn mang dk k c', 'label': 0}
# time--------> 36
# {'top_1': 3, 'top_2': 0}
# {'mean': 'Đầm hồng chất gì e?', 'label': 3}
# time--------> 37
# {'top_1': 6, 'top_2': 0}
# {'mean': 'Đũa 5 sao', 'label': 6}
# time--------> 38
# {'top_1': 1, 'top_2': 5}
# {'mean': 'Bưởi dồn đơn', 'label': 5}
# time--------> 39
# {'top_1': 2, 'top_2': 0}
# {'mean': 'Ms62 1 kem s 1 den S gộp đơn', 'label': 2}
# time--------> 40
# {}
# time--------> 41
# {'top_1': 2, 'top_2': 0}
# {'mean': 'M31 don don', 'label': 2}
# time--------> 42
# {'top_1': 3, 'top_2': 0}
# {}
# time--------> 43
# {}
# time--------> 44
# {}
# time--------> 45
# {}
# time--------> 46
# {}
# time--------> 47
# {}
# time--------> 48
# time--------> 49
# {}
# time--------> 50
# {}
# time--------> 51
# {}
# time--------> 52
# {}
# time--------> 53
# {}
# time--------> 54
# {}
# time--------> 55
# {}
# time--------> 56
# {}
# time--------> 57
# {}
# time--------> 58
# {}
# time--------> 59
# {}
# time--------> 60
# {}
# time--------> 61
# {}
# time--------> 62
# {}
# time--------> 63
# {}
# time--------> 64
# {}
# time--------> 65
# {}
# time--------> 66
# {}
# time--------> 67
# {}
# time--------> 68
# {}
# time--------> 69
# {}
# time--------> 70
# {}
# time--------> 71
# {}
# time--------> 72
# {}
# time--------> 73
# {}
# time--------> 74
# {}
# time--------> 75
# {}
# time--------> 76
# {}
# time--------> 77
# {}
# time--------> 78
# {}
# time--------> 79
# {}
# time--------> 80
# {}
# time--------> 81
# {}
# time--------> 82
# {}
# time--------> 83
# {}
# Done.

# %%
chatgpt_df = pd.DataFrame()
chatgpt_df["category"] = y_category
chatgpt_df["comment"] = y_comment
chatgpt_df["y_mean"] = y_mean
chatgpt_df["y_pred"] = y_pred
chatgpt_df["y_true"] = y_true
chatgpt_df.head()
# Out:
#     category                                            comment  \
# 0  accessory                           Lên bông tai xuping di e
# 1     others                                             Ádffff
# 2        fnb  anh chị ở chợ nguyen tri phương  tiệm vang ngo...
# 3        fnb                           Chị nói chuyen dễ thương
# 4        fnb                                    Lôn đanh gì chi
#
#                                               y_mean y_pred y_true
# 0                           Lên bông tai xuping di e      2      0
# 1                                             Ádffff      0      0
# 2  anh chị ở chợ nguyễn tri phương tiệm vàng ngọc hà      0      0
# 3                           Chị nói chuyện dễ thương      6      0
# 4                                    Lôn đanh gì chi      0      0

# %%
chatgpt_df = chatgpt_df.iloc[list(range(0,46,1))]
chatgpt_df
# Out:
#      category                                            comment  \
# 0   accessory                           Lên bông tai xuping di e
# 1      others                                             Ádffff
# 2         fnb  anh chị ở chợ nguyen tri phương  tiệm vang ngo...
# 3         fnb                           Chị nói chuyen dễ thương
# 4         fnb                                    Lôn đanh gì chi
# 5    clothing                                                  .
# 6      others                          Có chốt e chưa ạ ánh hồng
# 7         fnb                                           Hi 2 chú
# 8     grocery                         Lên quạt xạc cầm tay đi NA
# 9    clothing                                                  .
# 10     others                                               Chấm
# 11     others                                        oh vậy thôi
# 12        fnb                     Hôm nay xin Lộc 57 nha các Ông
# 13     others                      kim nguyen chốt giống máy bay
# 14   clothing                                       Hàng hôm kia
# 15     others                                Quay vong đi bé đẹp
# 16     others                                Đọc đúng tên rồi đó
# 17     others                                                 Zx
# 18    grocery                                         Chăn đi Na
# 19   clothing                                             Ctfiyc
# 20   clothing                      Dồn đơn bữa chưa gọi nka thảo
# 21     others                          Chuẩn kem trộn Tp cần thơ
# 22   clothing             E mua mấy lần rùi chị chút e ib đc nha
# 23    grocery                                                 Kk
# 24   clothing                                                Đcs
# 25     others                                     Tặng 3 50k 638
# 26   clothing                                           Tặng 560
# 27   clothing                                           tặng 824
# 28     others                                     Tặng 3 50k 963
# 29     others                                       Duyên Nguyễn
# 30   clothing                                           Tang 476
# 31     others                      Em seo đồng hồ cũ của em chưa
# 32     others                                       túi gia bn e
# 33     others                             Balô tôm còn kg Shopee
# 34   clothing                   Đơn hôm kia gọi chốt hết chưa em
# 35    grocery                                 Ng lớn mang dk k c
# 36   clothing                                 Đầm hồng chất gì e
# 37    grocery                                          Đũa 5 sao
# 38    grocery                                       Bưởi dồn đơn
# 39        fnb                      Ms62 1 kem s  1 den S gộp dơn
# 40     others                                          Em cá sấu
# 41     others                                        M31 don don
# 42   clothing                                        34 xanh rêu
# 43     others                                              Nam M
# 44   clothing                                            bộ quần
# 45   clothing                  Bộ sau lưng a kd đi ạ đen dài tay
#
#                                                y_mean y_pred y_true
# 0                            Lên bông tai xuping di e      2      0
# 1                                              Ádffff      0      0
# 2   anh chị ở chợ nguyễn tri phương tiệm vàng ngọc hà      0      0
# 3                            Chị nói chuyện dễ thương      6      0
# 4                                     Lôn đanh gì chi      0      0
# 5                                             'label'      0      0
# 6                           Có chốt e chưa ạ ánh hồng      2      0
# 7                                            Hi 2 chú      2      0
# 8                          Lên quạt xạc cầm tay đi NA      2      0
# 9                                                   .      0      0
# 10                                               Chấm      0      0
# 11                                        oh vậy thôi      6      0
# 12                     Hôm nay xin Lộc 57 nha các Ông      6      0
# 13                      kim nguyen chốt giống máy bay      4      0
# 14                                       Hàng hôm kia      1      0
# 15                                Quay vòng đi bé đẹp      0      0
# 16                                Đọc đúng tên rồi đó      1      0
# 17                                            'label'      0      0
# 18                                         Chăn đi Na      2      0
# 19      Các trường hợp khác hoặc không phân tích được      0      0
# 20                      Dồn đơn bữa chưa gọi nka thảo      2      0
# 21                          Chuẩn kem trộn Tp cần thơ      3      0
# 22             E mua mấy lần rùi chị chút e ib đc nha      1      0
# 23                                                 Kk      0      0
# 24                                            'label'      0      1
# 25                                     Tặng 3 50k 638      0      1
# 26                                           Tặng 560      2      1
# 27                                           tặng 824      3      1
# 28                                     Tặng 3 50k 963      3      1
# 29                                       Duyên Nguyễn      1      1
# 30                                           Tang 476      0      1
# 31                     Em seo đồng hồ cũ của em chưa?      1      2
# 32                                       túi gia bn e      0      2
# 33                                selecting a product      3      2
# 34                   Đơn hôm kia gọi chốt hết chưa em      4      2
# 35                         Người lớn mang được không?      0      2
# 36                                 Đầm hồng chất gì e      3      2
# 37                                          Đũa 5 sao      6      3
# 38                                           'output'      0      3
# 39                       Ms62 1 kem s 1 den S gộp dơn      1      3
# 40                                          Em cá sấu      1      3
# 41                                        M31 don don      1      3
# 42                                        34 xanh rêu      3      3
# 43        Không có thông tin cụ thể để xác định nhãn.      0      3
# 44                                            bộ quần      3      3
# 45                  Bộ sau lưng a kd đi ạ đen dài tay      3      3

# %%
chatgpt_df.shape
# Out:
# (84, 5)

# %%
y_pred_rp = [_ for _ in chatgpt_df.y_pred]
y_true_rp = [_ for _ in chatgpt_df.y_true]

# %%
print(set(y_pred_rp))
print(set(y_true_rp))
# Out:
# {'0', '2', '3'}
# {'6', '7', '5', '0', '3', '2', '1', '4'}

# %%
clf_report = classification_report(y_true_rp,
                                   y_pred_rp,
                                   labels=label_to_text,
                                   target_names=label_to_text,
                                   output_dict=True)

clf_report_df = pd.DataFrame(clf_report).iloc[:, :].T
clf_report_df["support"] = clf_report_df["support"].astype(int)

mask = np.zeros((len(label_to_text)+3, 4))
mask[:,3] = True
sns.heatmap(clf_report_df, mask=mask, cmap="Greens")
sns.heatmap(clf_report_df, alpha=0, cbar=False, annot=True, annot_kws={"size": 14, "color":"indianred"})

plt.show()



cm = []
for a0 in confusion_matrix(y_true_rp, y_pred_rp):
    s = sum(a0)
    cm.append([np.round(_/s, 2) for _ in a0])

plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', annot_kws={"size": 16})
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
all_candidates = [4, 5, 4, 5, 6, 7, 8, 7, 6, 5, 4, 4, 3, 5, 5, 5, 5, 5, 3, 2, 1, 9]
selected_label = sorted(all_candidates, key = lambda label: all_candidates.count(label))[-1]
selected_label
# Out:
# 5
