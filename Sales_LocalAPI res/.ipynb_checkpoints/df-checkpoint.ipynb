# %%
import os
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path_ = '/home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/gpt x30'
onlyfiles = [os.path.join(path_, f) for f in os.listdir(path_) if 
os.path.isfile(os.path.join(path_, f))]
for file_path in onlyfiles:
    print(file_path)
# Out:
# /home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/gpt x30/Elijah_predict_xxx.csv
# /home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/gpt x30/Elijah_predict_0.csv
# /home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/gpt x30/Jack_predict_xxx.csv
# /home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/gpt x30/Jack_predict_0.csv

# %%
df = pd.DataFrame()
for file_path in onlyfiles:
    tmp_ = pd.read_csv(file_path, dtype=str, keep_default_na=False)
    df = pd.concat([tmp_, df], axis=0)
label_names = list(range(0, 7+1))

df = df[df["y_text"] != "Error occurred"]

print(df.shape)
df.head()
# Out:
# (238, 5)
#   y_true y_pred                                             y_text  \
# 0      0      0                 Hello! How can I assist you today?
# 1      0      0  Xin lỗi, tôi không thể phân tích được bình luậ...
# 2      0      2  Đáp án là 2.\nBình luận "Chị chưa đc nè" không...
# 3      0      0  Đáp án là 0.\nBình luận "mm" không đưa ra đủ t...
# 4      0      0  Đáp án: 0.\nBình luận "Chị lai dể thương quá" ...
#
#                  content   category
# 0                      O  accessory
# 1                Cybmofx     others
# 2         Chị chưa đc nè     others
# 3                     mm     others
# 4  Chị lai dể thương quá  accessory

# %%
y_pred_manual = []
for text, pred in zip(df.y_text, df.y_pred):
    if "Đáp án" in text:
        pr = "0"
        for _ in range(text.index("Đáp án", len(text)):
            if _ in ["0", "1", "2", "3", "4", "5", "6", "7"]:
                pr = _
                break
        y_pred_manual.append(pr)
    else:
        y_pred_manual.
df["y_pred_"] = y_pred_manual
df
# Out:
#    y_true y_pred                                             y_text  \
# 0       0      0                 Hello! How can I assist you today?
# 1       0      0  Xin lỗi, tôi không thể phân tích được bình luậ...
# 2       0      4  Đáp án là 2.\nBình luận "Chị chưa đc nè" không...
# 3       0      0  Đáp án là 0.\nBình luận "mm" không đưa ra đủ t...
# 4       0      0  Đáp án: 0.\nBình luận "Chị lai dể thương quá" ...
# ..    ...    ...                                                ...
# 15      7      7  Dựa trên yêu cầu của bạn, tôi sẽ phân tích bìn...
# 16      7      3  Dựa trên yêu cầu của bạn, tôi sẽ phân tích bìn...
# 17      7      4  Dựa trên yêu cầu của bạn, tôi sẽ phân tích bìn...
# 18      7      7  Dựa trên yêu cầu của bạn, tôi sẽ phân tích bìn...
# 19      7      1  Dựa trên yêu cầu của bạn, tôi sẽ phân tích bìn...
#
#                                               content   category y_pred_
# 0                                                   O  accessory       0
# 1                                             Cybmofx     others       0
# 2                                      Chị chưa đc nè     others       4
# 3                                                  mm     others       0
# 4                               Chị lai dể thương quá  accessory       0
# ..                                                ...        ...     ...
# 15  E gai oi hủy Tuyet Linh dùm c nha C nghe ten d...     others       7
# 16                             xã sét váy nhung c nhe     others       3
# 17           Ui. Vậy chốt cho bạn khác giúp mình nhé.   clothing       4
# 18                                      c huỷ bbr nha     others       7
# 19                                          Hủy mã D1     others       1
#
# [238 rows x 6 columns]

# %%
y_true_str = [str(_) for _ in df.y_true] + label_names
y_pred_str = [str(_) for _ in df.y_pred] + label_names

clf_report = classification_report(y_true_str,
                                   y_pred_str,
                                   labels=label_names,
                                   target_names=label_names,
                                   output_dict=True)

clf_report_df = pd.DataFrame(clf_report).iloc[:, :].T
clf_report_df["support"] = clf_report_df["support"].astype(int)

mask = np.zeros((11, 4))
mask[:,3] = True
sns.heatmap(clf_report_df, mask=mask, cmap="Greens")
sns.heatmap(clf_report_df, alpha=0, cbar=False, annot=True, annot_kws={"size": 14, "color":"blueviolet"})

plt.show()



cm = confusion_matrix(y_true_str, y_pred_str)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', annot_kws={"size": 16})
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(label_names)
ax.yaxis.set_ticklabels(label_names)

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/numpy/lib/arraysetops.py:604: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/numpy/lib/arraysetops.py:604: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/numpy/lib/arraysetops.py:604: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# /home/aia/.virtualenvs/tadao-env/lib/python3.8/site-packages/numpy/lib/arraysetops.py:604: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 29
#      27 ax.set_ylabel('Actual Values ');
#      28 ## Ticket labels - List must be in alphabetical order
# ---> 29 ax.xaxis.set_ticklabels(label_names)
#      30 ax.yaxis.set_ticklabels(label_names)
#      32 # Display the visualization of the Confusion Matrix.
#
# File ~/.virtualenvs/tadao-env/lib/python3.8/site-packages/matplotlib/axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716 if isinstance(locator, mticker.FixedLocator):
#    1717     # Passing [] as a list of ticklabels is often used as a way to
#    1718     # remove all tick labels, so only error for > 0 ticklabels
#    1719     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720         raise ValueError(
#    1721             "The number of FixedLocator locations"
#    1722             f" ({len(locator.locs)}), usually from a call to"
#    1723             " set_ticks, does not match"
#    1724             f" the number of ticklabels ({len(ticklabels)}).")
#    1725     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1726     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of ticklabels (8).

# %%
df_2_3 = df.loc[df["y_true"] == "4"]
df_2_3 = df_2_3.loc[df_2_3["y_pred"] == "1"]
gpt_comments = df_2_3[["y_text", "content"]]
for i in range(len(gpt_comments)):
    x = gpt_comments.iloc[i]
    print(x.content)
    print()
    print(x.y_text)
    print("\n\n\n\n\n")
# Out:
# Đặt hàng Mã  Màu Số kí Số ĐTTrên cùng 1 tin nhắn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích các bình luận sau: "Đặt hàng Mã Màu Số kí Số ĐTTrên cùng 1 tin nhắn."
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Có sự yêu cầu về việc đặt hàng, bao gồm mã sản phẩm, màu sắc, số lượng và số điện thoại.
# Đáp án: 0. Không phân tích được.
# Giải thích: Không có thông tin cụ thể để xác định mục đích hoặc nội dung của bình luận này.
# Vui lòng cung cấp thêm ví dụ hoặc thông tin chi tiết nếu bạn muốn phân tích các bình luận khác.
#
#
#
#
#
#
# Đặt Hàng Mã Màu số Ký SDT chia sẻ bài Tự chốt Đơn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Đặt Hàng Mã Màu số Ký SDT chia sẻ bài Tự chốt Đơn."
# Đáp án: 1. Tag tên riêng hoặc chia sẻ bài.
# Giải thích: Bình luận này bao gồm việc đặt hàng, đưa ra mã sản phẩm, màu sắc, số lượng, số điện thoại và yêu cầu chia sẻ bài đăng.
# Đáp án: 4. Đã chốt đơn.
# Giải thích: Bình luận này cho thấy người dùng đã xác nhận và chốt đơn hàng.
# Vui lòng cung cấp thêm ví dụ hoặc thông tin chi tiết nếu bạn muốn phân tích các bình luận khác.
#
#
#
#
#
#
# Chia sẽ mua hàng Giá sỉ Đặt hàng MãMàuSố KíSố ĐTTrên cùng 1 tin nhắn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Chia sẽ mua hàng Giá sỉ Đặt hàng MãMàuSố KíSố ĐTTrên cùng 1 tin nhắn."
# Đáp án: 1. Tag tên riêng hoặc chia sẻ bài.
# Giải thích: Bình luận này yêu cầu chia sẻ thông tin về việc mua hàng với giá sỉ và có thể bao gồm việc tag tên riêng hoặc chia sẻ bài đăng.
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này đề cập đến việc đặt hàng và yêu cầu cung cấp thông tin như mã sản phẩm, màu sắc, số lượng và số điện thoại.
# Vui lòng cung cấp thêm thông tin chi tiết nếu bạn muốn phân tích các bình luận khác.
#
#
#
#
#
#
# Đặt hàng Mã  Màu Số kí Số ĐT trên cùng 1 Tin nhắn5
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Đặt hàng Mã Màu Số kí Số ĐT trên cùng 1 Tin nhắn5."
# Đáp án: 5. Không thích sản phẩm.
# Giải thích: Bình luận này cho thấy người viết đang yêu cầu đặt hàng với các thông tin về mã sản phẩm, màu sắc, số kí, số điện thoại được gửi trong cùng một tin nhắn. Tuy nhiên, cuối cùng người viết bày tỏ không thích sản phẩm.
#
#
#
#
#
#
# Thảm 1m6 135k
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Thảm 1m6 135k."
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này đưa ra thông tin về sản phẩm "thảm" với kích thước 1m6 và giá 135k. Người viết đang chỉ định thông số cụ thể cho sản phẩm, trong trường hợp này là kích thước và giá cả.
#
#
#
#
#
#
# Chia sẽ livestream mua hang giá sỉĐặt hàng MãMàu Số Kí Số ĐTTrên cùng 1 tin nhắn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Chia sẽ livestream mua hàng giá sỉ Đặt hàng Mã Màu Số Kí Số ĐT Trên cùng 1 tin nhắn."
# Đáp án: 1. Tag tên riêng hoặc chia sẻ bài.
# Giải thích: Bình luận này đề cập đến việc chia sẻ thông tin về livestream mua hàng giá sỉ. Người viết muốn tag tên riêng hoặc chia sẻ bài viết để thông báo cho người khác biết về sự kiện này.
#
#
#
#
#
#
# Đặt hàng MãSố ĐT Trên cùng 1tin nhắn nhé
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Đặt hàng MãSố ĐT Trên cùng 1 tin nhắn nhé".
# Đáp án: 2. Đặt câu hỏi hoặc đang thắc mắc.
# Giải thích: Bình luận này yêu cầu sự xác nhận hoặc đặt câu hỏi về việc đặt hàng. Người viết muốn biết liệu việc đặt hàng có thể được thực hiện thông qua việc gửi mã sản phẩm và số điện thoại trong cùng một tin nhắn hay không.
#
#
#
#
#
#
# Đặt hàng MãMàu Số ĐT Trên cùng 1 tin nhắn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Đặt hàng MãMàu Số ĐT Trên cùng 1 tin nhắn".
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này đề cập đến việc đặt hàng và yêu cầu thông tin về Mã sản phẩm, Màu sắc và Số điện thoại được gửi trong cùng một tin nhắn. Người viết muốn chọn các thông số cụ thể cho sản phẩm mà họ muốn mua.
#
#
#
#
#
#
# Đặt Hàng  Mã  Màu  SDT cùng 1 tin nhắn Chia sẻ 3 nhóm giảm giá
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Đặt Hàng Mã Màu SDT cùng 1 tin nhắn Chia sẻ 3 nhóm giảm giá".
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này chứa các yếu tố đặt hàng như Mã sản phẩm, Màu sắc và Số điện thoại được đề cập trong cùng một tin nhắn. Đồng thời, người viết cũng đề cập đến việc chia sẻ 3 nhóm giảm giá, nhưng không có câu hỏi hoặc thắc mắc cụ thể. Từ đó, chúng ta có thể hiểu rằng người viết đang chọn thông số cho sản phẩm và chia sẻ thông tin về các nhóm giảm giá.
#
#
#
#
#
#
# Mă 1 soàn dồn đơn trưa
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Mă 1 soàn dồn đơn trưa".
# Đáp án: 4. Đã chốt đơn.
# Giải thích: Bình luận này cho thấy người viết đã chốt đơn hàng trong thời gian trưa. Mặc dù bình luận không rõ ràng về sản phẩm cụ thể hoặc thông tin khác liên quan, nhưng việc đề cập đến "đơn" và "chốt" cho thấy người viết đã hoàn tất quá trình đặt hàng.
#
#
#
#
#
#
# Chia sẽ mua hàng giá sỉĐặt hàng MãSô ĐT Số kí trên cùng 1 tin nhắn
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Chia sẽ mua hàng giá sỉ Đặt hàng MãSố ĐT Số kí trên cùng 1 tin nhắn".
# Đáp án: 2. Đặt câu hỏi hoặc đang thắc mắc.
# Giải thích: Bình luận này chứa yếu tố đặt câu hỏi hoặc thắc mắc về việc mua hàng giá sỉ và việc đặt hàng thông qua việc yêu cầu mã sản phẩm (MãSố), số điện thoại (ĐT), và số kí trên cùng một tin nhắn. Người viết có vẻ như đang muốn tìm hiểu thông tin về cách mua hàng và yêu cầu đặt hàng.
#
#
#
#
#
#
# ĐẶT HÀNG MÃ SỐ ĐIỆN THOẠITRÊN CÙNG 1TIN NHẮN
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "ĐẶT HÀNG MÃ SỐ ĐIỆN THOẠI TRÊN CÙNG 1 TIN NHẮN".
# Đáp án: 4. Đã chốt đơn.
# Giải thích: Bình luận này cho thấy người viết đã đặt hàng bằng cách cung cấp mã số điện thoại và yêu cầu đặt hàng trong cùng một tin nhắn. Việc "đặt hàng" và việc cung cấp thông tin liên lạc (mã số điện thoại) cho shop cho thấy rằng người viết đã hoàn thành quá trình đặt mua hàng và chốt đơn.
#
#
#
#
#
#
# Chia sẽ mua hàng giá sỉĐẶT HÀNG MÃ MÀUSỐ KÍ SỐ ĐT TRÊN CÙNG 1 TIN NHẮN5
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "Chia sẽ mua hàng giá sỉĐẶT HÀNG MÃ MÀUSỐ KÍ SỐ ĐT TRÊN CÙNG 1 TIN NHẮN5".
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này bắt đầu bằng việc chia sẻ thông tin về việc mua hàng giá sỉ, sau đó người viết tiếp tục yêu cầu đặt hàng bằng cách cung cấp mã màu, số kí, và số điện thoại trong cùng một tin nhắn. Việc cung cấp thông tin về mã màu và số kí cho thấy người viết đang chọn thông số cho sản phẩm.
#
#
#
#
#
#
# 1 Màu đen 73ki899
#
# Dựa trên yêu cầu của bạn, dưới đây là phân tích bình luận sau: "1 Màu đen 73ki899".
# Đáp án: 3. Chọn thông số cho sản phẩm.
# Giải thích: Bình luận này đề cập đến một số thông số của sản phẩm, bao gồm màu sắc ("Màu đen") và một chuỗi kí tự ("73ki899"). Có thể hiểu rằng người bình luận đang chọn thông số của sản phẩm và có thể đề cập đến một mã, số, hoặc thông tin khác để xác định sản phẩm cụ thể mà họ quan tâm.

# %%
tmp = pd.read_csv("/home/aia/Nhat/ChatGPT-Conversation/Multi_Acc/sales.csv", dtype=str, keep_default_na=False)

# %%
x = list(tmp.label)
for i in range(8):
    print(i, x.count(str(i)))
# Out:
# 0 26336
# 1 8995
# 2 36579
# 3 49782
# 4 30
# 5 71
# 6 2097
# 7 53

# %%
df_4 = tmp[tmp["label"]=="4"].sample(n=30)
# Out:
#             time     livestream_id        comment_owner_id  \
# 98166   00:02:16  3581423565298695         100041991400257
# 123938       0.0                 0               nhat.pham
# 27483   01:35:55   567417977156414         100028920736843
# 92390   00:23:15  2833627223560319             vievie.tran
# 123941       0.0                 0               nhat.pham
# 27485   01:37:03   567417977156414       chon.binhyen.9693
# 15486   00:35:12   528749761102201         100014539205027
# 98172   00:14:56  3581423565298695         myphamhongtrang
# 67339   01:57:21   662002697809551         100037128188063
# 123940       0.0                 0               nhat.pham
# 98795   01:23:05   675484853403825        thuy.vo.18062533
# 103283  00:05:33  2868987130089270         100041991400257
# 12752      146.0   201758594728568  junishop.thoitrangSale
# 101169  00:01:24  1044605399320731         100041991400257
# 102269  00:00:36  1083670332066023         100041991400257
# 83928   00:05:38  3227735723997265             vievie.tran
# 101455  03:05:16   665797820990757         100039020081492
# 98452   00:02:14  2757221087938910         100041991400257
# 103376  00:01:51  1035056400254341         100041991400257
# 37405   01:50:26   400810140957468         hoaiphuongmusic
# 117899  00:36:38  3460768107378238                 Huyen.W
# 101192  00:23:15  1044605399320731        tavinh0987091666
# 98751   00:02:05   675484853403825         100041991400257
# 100139  00:03:28   404075894302649         100041991400257
# 52898   00:28:36   998607537312775         ngocthuytrananh
# 123939       0.0                 0               nhat.pham
# 98170   00:07:11  3581423565298695        tavinh0987091666
# 123942       0.0                 0               nhat.pham
# 103875  00:01:31  3948963528460890         100041991400257
# 102072  00:01:42   407968893709223         100041991400257
#
#                                                   comment label   category
# 98166           Đặt hàng MãMàu Số ĐT Trên cùng 1 tin nhắn     4  accessory
# 123938                            Em đặt sợi dây chuyền a     4  accessory
# 27483                                       Thảm 1m6 135k     4    grocery
# 92390   Khách mới lên đủ thông tin  địa chỉ  sđt  để s...     4   clothing
# 123941            Gui chiec nhan do ve q4 qua shipper nhe     4  accessory
# 27485                                                Thảm     4    grocery
# 15486                               Bộ vest đen sz M đi c     4    grocery
# 98172   Đặt Hàng  Mã  Màu  SDT cùng 1 tin nhắn Chia sẻ...     4  accessory
# 67339   Hàng tới chị kêu shiper trừ tiền lộn ra nhưng ...     4   clothing
# 123940               Chi chon cai dong ho mau nau den nhe     4  accessory
# 98795                                   1 Màu đen 73ki899     4  accessory
# 103283         Đặt hàng  mã  sdt trên cùng một tin nhắn 2     4  accessory
# 12752   Chốt hàng: Khách mới - Mã + SĐTHotline:0...     4   clothing
# 101169   Đặt hàng Mã  Màu Số kí Số ĐTTrên cùng 1 tin nhắn     4  accessory
# 102269       ĐẶT HÀNG MÃ SỐ ĐIỆN THOẠITRÊN CÙNG 1TIN NHẮN     4  accessory
# 83928   Giá  mẫu  số kí  thông tinDồn đơn trưa nay sẽ ...     4   clothing
# 101455                             Mă 1 soàn dồn đơn trưa     4  accessory
# 98452   Chia sẽ mua hàng Giá sỉ Đặt hàng MãMàuSố KíSố ...     4  accessory
# 103376           Đặt hàng MãSố ĐT Trên cùng 1tin nhắn nhé     4  accessory
# 37405                                     C tặng em 30tr1     4        fnb
# 117899  Jumb đen lúc chiều nếu có thì đi chung đơn của...     4     others
# 101192  Đặt Hàng Mã Màu số Ký SDT chia sẻ bài Tự chốt Đơn     4  accessory
# 98751   Đặt hàng Mã  Màu Số kí Số ĐT trên cùng 1 Tin n...     4  accessory
# 100139  Chia sẽ mua hàng giá sỉĐặt hàng MãSô ĐT Số kí ...     4  accessory
# 52898                                       Vay da size l     4     others
# 123939               Váy ngắn size S nha c sđt 0559696696     4   clothing
# 98170   Đặt Hàng Mã  Màu  SDT trên cùng tin nhắn chia ...     4  accessory
# 123942                              Chot don X25 nha shop     4  accessory
# 103875  Chia sẽ mua hàng giá sỉĐẶT HÀNG MÃ MÀUSỐ KÍ SỐ...     4  accessory
# 102072  Chia sẽ livestream mua hang giá sỉĐặt hàng MãM...     4  accessory
